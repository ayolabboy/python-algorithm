# %%
lst = [1,2,3,4]


max_lst = max(lst)
min_lst = min(lst)

sum_lst = max_lst + min_lst
minus_lst = max_lst - min_lst 
multi_lst = max_lst * min_lst 
div_lst = max_lst * min_lst 

print(sum_lst)
print(minus_lst)
print(multi_lst)
print(div_lst)
# Out:
# 5
# 3
# 4
# 4
