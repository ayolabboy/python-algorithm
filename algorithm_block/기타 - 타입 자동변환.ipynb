# %%
## ㅇ
a = [1.2, 2.5, 3.7, 4.6]
for i in range(len(a)):
    a[i] = int(a[i])
    
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [1.2, 2.5, 3.7, 4.6]
a = list(map(int, a))
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [1.2, 2.5, 3.7, 4.6]
a = list(map(float, a))
print(a)
# Out:
# [1.2, 2.5, 3.7, 4.6]

# %%
a = [1.2, 2.5, 3.7, 4.6]
a = list(map(str, a))
print(a)
# Out:
# ['1.2', '2.5', '3.7', '4.6']

# %% [markdown]
# ![20200403_151317.png](attachment:20200403_151317.png)
